# %% [markdown]
# # 👍 중간고사 - 미완성 문제해결 프로그램

# %% [markdown]
# ## [시험문제]
# - 주석의 안내에 따라 미완성 프로그램을 완성하고, 중간고사 시험문제 11번 ~ 15번까지의 질문에 답하세요.

# %% [markdown]
# ## [문제상황 - 해결할 문제 정의]

# %% [markdown]
# - 경상남도 김해시는 친환경 도시를 슬로건으로 전기 자전거 스테이션을 설치하였다.
# - 금년에 김해시 사업계획에 따라 전기 자전거 활성화를 위하여 위치정보 조회 서비스를 홈페이지에 게시하기로 하였다.
# - 자전거 보관소 데이터 조회 후 지도에 위치를 표시하는 핵심 서비스 프로그램을 완성하세요.

# %% [markdown]
# - 공공데이터 포털 : https://www.data.go.kr/

# %% [markdown]
# - 공공데이터포털의 데이터명 : 경상남도 김해시_전기자전거 스테이션 위치정보

# %% [markdown]
# ### Open API 이용 데이터 수집

# %%
# Open API 통신 실패로 데이터를 받아오지 못하는 경우 대신할 데이터
open_api_data = '''
{"status":"999","message":"정상 처리 되었습니다.","data":[{"mgtNo":"STATION_001","name":"봉황역","xCoordinate":"128.8736411","yCoordinate":"35.2277057","addr":"경상남도 김해시 외동 1264"},{"mgtNo":"STATION_002","name":"수로왕릉역","xCoordinate":"128.872086162507","yCoordinate":"35.2329938518363","addr":"김해시 외동 1297"},{"mgtNo":"STATION_003","name":"수로왕릉","xCoordinate":"128.8789361","yCoordinate":"35.2334009","addr":"김해시 서상동 335-1"},{"mgtNo":"STATION_004","name":"대성동고분박물관","xCoordinate":"128.8728810","yCoordinate":"35.2348520","addr":"김해시 봉황동 453-1"},{"mgtNo":"STATION_005","name":"박물관역","xCoordinate":"128.8718979","yCoordinate":"35.2400377","addr":"김해시 내동 1147"},{"mgtNo":"STATION_006","name":"수로왕비릉","xCoordinate":"128.877676954359","yCoordinate":"35.2425291957211","addr":"김해시 구산동 93-1"},{"mgtNo":"STATION_007","name":"국립김해박물관","xCoordinate":"128.872223171877","yCoordinate":"35.2437152642491","addr":"김해시 구산동 1032"},{"mgtNo":"STATION_008","name":"연지공원역","xCoordinate":"128.8696941","yCoordinate":"35.2493142","addr":"김해시 구산동 1072-16"},{"mgtNo":"STATION_009","name":"연지공원","xCoordinate":"128.8697906","yCoordinate":"35.2447422","addr":"김해시 내동 1068"},{"mgtNo":"STATION_010","name":"거북공원","xCoordinate":"128.8656057","yCoordinate":"35.2370078","addr":"김해시 내동 1116-2"},{"mgtNo":"STATION_011","name":"공주공원","xCoordinate":"128.8684638","yCoordinate":"35.2345124","addr":"김해시 내동 1146-7"}]}
'''

# %%
# 공공데이터포털의 Open API를 이용한 데이터 수집
import ?  # 문제 1-1 : 아래 코드를 수정하지 않고 정상 구동 되도록 "?" 에 알맞는 패키지명을 작성하세요.

url = 'https://smartcity.gimhae.go.kr/smart_tour/dashboard/api/publicData/location/bicycleStation'

# Open API 통신 실패시 처리를 위한 try ~ exept 블록 처리
try:
    response = requests.get(url, verify=False, stream=True, timeout=5)
    data = response.content.decode('utf-8')  # 데이터를 받았으면 문자셋을 utf-8로 변형
except:
    data = open_api_data # 통신에 실패했다면 이미 준비한 데이터를 이용하도록 처리

# 데이터 수집결과 출력
print(type(data), data)
# Out:
# <class 'str'>
# {"status":"999","message":"정상 처리 되었습니다.","data":[{"mgtNo":"STATION_001","name":"봉황역","xCoordinate":"128.8736411","yCoordinate":"35.2277057","addr":"경상남도 김해시 외동 1264"},{"mgtNo":"STATION_002","name":"수로왕릉역","xCoordinate":"128.872086162507","yCoordinate":"35.2329938518363","addr":"김해시 외동 1297"},{"mgtNo":"STATION_003","name":"수로왕릉","xCoordinate":"128.8789361","yCoordinate":"35.2334009","addr":"김해시 서상동 335-1"},{"mgtNo":"STATION_004","name":"대성동고분박물관","xCoordinate":"128.8728810","yCoordinate":"35.2348520","addr":"김해시 봉황동 453-1"},{"mgtNo":"STATION_005","name":"박물관역","xCoordinate":"128.8718979","yCoordinate":"35.2400377","addr":"김해시 내동 1147"},{"mgtNo":"STATION_006","name":"수로왕비릉","xCoordinate":"128.877676954359","yCoordinate":"35.2425291957211","addr":"김해시 구산동 93-1"},{"mgtNo":"STATION_007","name":"국립김해박물관","xCoordinate":"128.872223171877","yCoordinate":"35.2437152642491","addr":"김해시 구산동 1032"},{"mgtNo":"STATION_008","name":"연지공원역","xCoordinate":"128.8696941","yCoordinate":"35.2493142","addr":"김해시 구산동 1072-16"},{"mgtNo":"STATION_009","name":"연지공원","xCoordinate":"128.8697906","yCoordinate":"35.2447422","addr":"김해시 내동 1068"},{"mgtNo":"STATION_010","name":"거북공원","xCoordinate":"128.8656057","yCoordinate":"35.2370078","addr":"김해시 내동 1116-2"},{"mgtNo":"STATION_011","name":"공주공원","xCoordinate":"128.8684638","yCoordinate":"35.2345124","addr":"김해시 내동 1146-7"}]}

# %%
# 수집결과 데이터 처리 : string자료형으로 dict자료형으로 변환
import json

after_data = json.?(data) # 문제 1-2 : string 자료형인 data 값을 dict 자료형으로 변환하는 코드를 작성하세요.
after_data
# Out:
# {'status': '999',
#  'message': '정상 처리 되었습니다.',
#  'data': [{'mgtNo': 'STATION_001',
#    'name': '봉황역',
#    'xCoordinate': '128.8736411',
#    'yCoordinate': '35.2277057',
#    'addr': '경상남도 김해시 외동 1264'},
#   {'mgtNo': 'STATION_002',
#    'name': '수로왕릉역',
#    'xCoordinate': '128.872086162507',
#    'yCoordinate': '35.2329938518363',
#    'addr': '김해시 외동 1297'},
#   {'mgtNo': 'STATION_003',
#    'name': '수로왕릉',
#    'xCoordinate': '128.8789361',
#    'yCoordinate': '35.2334009',
#    'addr': '김해시 서상동 335-1'},
#   {'mgtNo': 'STATION_004',
#    'name': '대성동고분박물관',
#    'xCoordinate': '128.8728810',
#    'yCoordinate': '35.2348520',
#    'addr': '김해시 봉황동 453-1'},
#   {'mgtNo': 'STATION_005',
#    'name': '박물관역',
#    'xCoordinate': '128.8718979',
#    'yCoordinate': '35.2400377',
#    'addr': '김해시 내동 1147'},
#   {'mgtNo': 'STATION_006',
#    'name': '수로왕비릉',
#    'xCoordinate': '128.877676954359',
#    'yCoordinate': '35.2425291957211',
#    'addr': '김해시 구산동 93-1'},
#   {'mgtNo': 'STATION_007',
#    'name': '국립김해박물관',
#    'xCoordinate': '128.872223171877',
#    'yCoordinate': '35.2437152642491',
#    'addr': '김해시 구산동 1032'},
#   {'mgtNo': 'STATION_008',
#    'name': '연지공원역',
#    'xCoordinate': '128.8696941',
#    'yCoordinate': '35.2493142',
#    'addr': '김해시 구산동 1072-16'},
#   {'mgtNo': 'STATION_009',
#    'name': '연지공원',
#    'xCoordinate': '128.8697906',
#    'yCoordinate': '35.2447422',
#    'addr': '김해시 내동 1068'},
#   {'mgtNo': 'STATION_010',
#    'name': '거북공원',
#    'xCoordinate': '128.8656057',
#    'yCoordinate': '35.2370078',
#    'addr': '김해시 내동 1116-2'},
#   {'mgtNo': 'STATION_011',
#    'name': '공주공원',
#    'xCoordinate': '128.8684638',
#    'yCoordinate': '35.2345124',
#    'addr': '김해시 내동 1146-7'}]}

# %%
# dict 자료형으로 변환되었는지 확인
type(after_data)
# Out:
# dict

# %%
# 필수 데이터인 각 지역별 정보만 추출
x_data = after_data['data']
x_data
# Out:
# [{'mgtNo': 'STATION_001',
#   'name': '봉황역',
#   'xCoordinate': '128.8736411',
#   'yCoordinate': '35.2277057',
#   'addr': '경상남도 김해시 외동 1264'},
#  {'mgtNo': 'STATION_002',
#   'name': '수로왕릉역',
#   'xCoordinate': '128.872086162507',
#   'yCoordinate': '35.2329938518363',
#   'addr': '김해시 외동 1297'},
#  {'mgtNo': 'STATION_003',
#   'name': '수로왕릉',
#   'xCoordinate': '128.8789361',
#   'yCoordinate': '35.2334009',
#   'addr': '김해시 서상동 335-1'},
#  {'mgtNo': 'STATION_004',
#   'name': '대성동고분박물관',
#   'xCoordinate': '128.8728810',
#   'yCoordinate': '35.2348520',
#   'addr': '김해시 봉황동 453-1'},
#  {'mgtNo': 'STATION_005',
#   'name': '박물관역',
#   'xCoordinate': '128.8718979',
#   'yCoordinate': '35.2400377',
#   'addr': '김해시 내동 1147'},
#  {'mgtNo': 'STATION_006',
#   'name': '수로왕비릉',
#   'xCoordinate': '128.877676954359',
#   'yCoordinate': '35.2425291957211',
#   'addr': '김해시 구산동 93-1'},
#  {'mgtNo': 'STATION_007',
#   'name': '국립김해박물관',
#   'xCoordinate': '128.872223171877',
#   'yCoordinate': '35.2437152642491',
#   'addr': '김해시 구산동 1032'},
#  {'mgtNo': 'STATION_008',
#   'name': '연지공원역',
#   'xCoordinate': '128.8696941',
#   'yCoordinate': '35.2493142',
#   'addr': '김해시 구산동 1072-16'},
#  {'mgtNo': 'STATION_009',
#   'name': '연지공원',
#   'xCoordinate': '128.8697906',
#   'yCoordinate': '35.2447422',
#   'addr': '김해시 내동 1068'},
#  {'mgtNo': 'STATION_010',
#   'name': '거북공원',
#   'xCoordinate': '128.8656057',
#   'yCoordinate': '35.2370078',
#   'addr': '김해시 내동 1116-2'},
#  {'mgtNo': 'STATION_011',
#   'name': '공주공원',
#   'xCoordinate': '128.8684638',
#   'yCoordinate': '35.2345124',
#   'addr': '김해시 내동 1146-7'}]

# %%
# 각 지역정보를 pandas 데이터프레임으로 변환
import pandas as pd

real_data = pd.?(x_data) # 문제 1-3 : dict 자료형인 x_data 값을 pandas 데이터프레임 객체로 변환하는 코드를 작성하세요.
real_data
# Out:
#           mgtNo      name       xCoordinate       yCoordinate  \
# 0   STATION_001       봉황역       128.8736411        35.2277057
# 1   STATION_002     수로왕릉역  128.872086162507  35.2329938518363
# 2   STATION_003      수로왕릉       128.8789361        35.2334009
# 3   STATION_004  대성동고분박물관       128.8728810        35.2348520
# 4   STATION_005      박물관역       128.8718979        35.2400377
# 5   STATION_006     수로왕비릉  128.877676954359  35.2425291957211
# 6   STATION_007   국립김해박물관  128.872223171877  35.2437152642491
# 7   STATION_008     연지공원역       128.8696941        35.2493142
# 8   STATION_009      연지공원       128.8697906        35.2447422
# 9   STATION_010      거북공원       128.8656057        35.2370078
# 10  STATION_011      공주공원       128.8684638        35.2345124
#
#                 addr
# 0   경상남도 김해시 외동 1264
# 1        김해시 외동 1297
# 2      김해시 서상동 335-1
# 3      김해시 봉황동 453-1
# 4        김해시 내동 1147
# 5       김해시 구산동 93-1
# 6       김해시 구산동 1032
# 7    김해시 구산동 1072-16
# 8        김해시 내동 1068
# 9      김해시 내동 1116-2
# 10     김해시 내동 1146-7

# %% [markdown]
# - 각 컬럼이 의미하는 내용
#     - mgtNo : 스테이션 관리 번호
#     - name : 스테이션 이름
#     - xCoordinate : 경도 (왼쪽 또는 오른쪽에서 떨어진 거리)
#     - yCoordinate : 위도 (남쪽 또는 북쪽에서 떨어진 거리)
#     - addr : 주소

# %%
# 각 컬럼의 컬럼명, 자료형, 결측치, 메모리 사용량 등 확인
real_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mgtNo        11 non-null     object
#  1   name         11 non-null     object
#  2   xCoordinate  11 non-null     object
#  3   yCoordinate  11 non-null     object
#  4   addr         11 non-null     object
# dtypes: object(5)
# memory usage: 568.0+ bytes

# %%
# xCoordinate, yCoordinate 자료형 변경
# 문제 1-4 : real_data 데이터프레임의 xCoordinate, yCoordinate 컬럼의 자료형을 float로 변환하는 코드를 작성하세요.
real_data['xCoordinate'] = real_data['xCoordinate'].?('float')
real_data['yCoordinate'] = real_data['yCoordinate'].?('float')

# 각 컬럼의 컬럼명, 자료형, 결측치, 메모리 사용량 등 확인
real_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mgtNo        11 non-null     object
#  1   name         11 non-null     object
#  2   xCoordinate  11 non-null     float64
#  3   yCoordinate  11 non-null     float64
#  4   addr         11 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 568.0+ bytes

# %%
# 불필요한 컬럼으로 생각되는 mgtNo 컬럼을 제거
real_data = real_data.drop(?) # 문제 1-5 : real_data 데이터프레임의 mgtNo 컬럼을 제거하는 코드를 완성하세요.
real_data.head()
# Out:
#        name  xCoordinate  yCoordinate              addr
# 0       봉황역   128.873641    35.227706  경상남도 김해시 외동 1264
# 1     수로왕릉역   128.872086    35.232994       김해시 외동 1297
# 2      수로왕릉   128.878936    35.233401     김해시 서상동 335-1
# 3  대성동고분박물관   128.872881    35.234852     김해시 봉황동 453-1
# 4      박물관역   128.871898    35.240038       김해시 내동 1147

# %%
# 각 컬럼별 결측치 갯수 확인
real_data.isnull().sum()
# Out:
# name           0
# xCoordinate    0
# yCoordinate    0
# addr           0
# dtype: int64

# %%
# 수치형 데이터에 대한 갯수, 평균, 표준편차, 최소, 최대, 사분위 값등 기초통계량 확인
# 문제 1-6 : real_data 데이터프레임의 xCoordinate 의 평균은 얼마인가요 ?
real_data.describe()
# Out:
#        xCoordinate  yCoordinate
# count    11.000000    11.000000
# mean    128.872082    35.238256
# std       0.003839     0.006367
# min     128.865606    35.227706
# 25%     128.869742    35.233957
# 50%     128.872086    35.237008
# 75%     128.873261    35.243122
# max     128.878936    35.249314

# %%
# folium 패키지를 이용하여 "봉황역" 스테이션의 위도, 경도를 지도에 마커로 표시
import ? # 문제 1-7 : 아래 코드를 수정하지 않고 정상 구동 되도록 "?" 에 알맞는 패키지명을 작성하세요.

map_figure = folium.Figure(width=700, height=350) # map 크기 변경
map_ = folium.Map(location=[35.2277057, 128.8736411], zoom_start=17).add_to(map_figure) # 봉황역 스테이션 위도, 경도를 중심으로 지도 구성

popup = folium.Popup('봉황역', min_width=200, max_width=200) # 봉황역 마커 클릭시 출력할 팝업 메세지 준비
folium.Marker([35.2277057, 128.8736411], popup=popup, tooltip='경상남도 김해시 외동 1264').add_to(map_) # 봉황역 마커 출력
map_  # map 출력
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfe894d0dcbef68a99596192b81a5353 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfe894d0dcbef68a99596192b81a5353&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfe894d0dcbef68a99596192b81a5353 = L.map(
#                 &quot;map_bfe894d0dcbef68a99596192b81a5353&quot;,
#                 {
#                     center: [35.2277057, 128.8736411],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bf7f5b6f93a6fbd44dadc1d22cf16ff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bfe894d0dcbef68a99596192b81a5353);
#
#
#             var marker_4b93c8d3a94b516b510a134461f7721a = L.marker(
#                 [35.2277057, 128.8736411],
#                 {}
#             ).addTo(map_bfe894d0dcbef68a99596192b81a5353);
#
#
#         var popup_3c73519e95c0ad4a3a4a8b3225e01af1 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_6d37eb271c9507f8bf82915b2fabc455 = $(`&lt;div id=&quot;html_6d37eb271c9507f8bf82915b2fabc455&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;봉황역&lt;/div&gt;`)[0];
#             popup_3c73519e95c0ad4a3a4a8b3225e01af1.setContent(html_6d37eb271c9507f8bf82915b2fabc455);
#
#
#         marker_4b93c8d3a94b516b510a134461f7721a.bindPopup(popup_3c73519e95c0ad4a3a4a8b3225e01af1)
#         ;
#
#
#
#
#             marker_4b93c8d3a94b516b510a134461f7721a.bindTooltip(
#                 `&lt;div&gt;
#                      경상남도 김해시 외동 1264
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" width="700" height="350"style="border:none !important;" "allowfullscreen" "webkitallowfullscreen" "mozallowfullscreen"></iframe>

# %%
# folium 패키지를 이용하여 모든 스테이션을 지도에 마커로 출력
import folium

map_figure = folium.Figure(width=700, height=350) # map 크기 변경
map_ = folium.Map(location=[35.2277057, 128.8736411], zoom_start=14).add_to(map_figure) # 봉황역 스테이션 위도, 경도를 중심으로 지도 구성

# 문제 1-8 : real_data 데이터프레임 각각의 Row 값을 읽기 위하여 iterrows() 함수를 사용하는 코드를 완성하세요.
for row_index, ? in real_data.iterrows():
    popup = folium.Popup(row['name'], min_width=200, max_width=200) # 마커 클릭시 출력할 팝업 메세지 준비
    folium.Marker([row.yCoordinate, row.xCoordinate], popup=popup, tooltip=row.addr).add_to(map_) # 마커 출력
map_  # map 출력
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c67271472c9d743c7ab0e31465754907 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c67271472c9d743c7ab0e31465754907&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c67271472c9d743c7ab0e31465754907 = L.map(
#                 &quot;map_c67271472c9d743c7ab0e31465754907&quot;,
#                 {
#                     center: [35.2277057, 128.8736411],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_428c0beae046f9625a5172d116c3cd2b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c67271472c9d743c7ab0e31465754907);
#
#
#             var marker_7052799f2a4fe341f5a242d1847d2f2c = L.marker(
#                 [35.2277057, 128.8736411],
#                 {}
#             ).addTo(map_c67271472c9d743c7ab0e31465754907);
#
#
#         var popup_cab967982988b07cd67fde926d31540c = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_a06d348cb1da5a5cb414dec1e3acb6cb = $(`&lt;div id=&quot;html_a06d348cb1da5a5cb414dec1e3acb6cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;봉황역&lt;/div&gt;`)[0];
#             popup_cab967982988b07cd67fde926d31540c.setContent(html_a06d348cb1da5a5cb414dec1e3acb6cb);
#
#
#         marker_7052799f2a4fe341f5a242d1847d2f2c.bindPopup(popup_cab967982988b07cd67fde926d31540c)
#         ;
#
#
#
#
#             marker_7052799f2a4fe341f5a242d1847d2f2c.bindTooltip(
#                 `&lt;div&gt;
#                      경상남도 김해시 외동 1264
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_46d499ae4e083cafc2db803d9b3e5cdf = L.marker(
#                 [35.2329938518363, 128.872086162507],
#                 {}
#             ).addTo(map_c67271472c9d743c7ab0e31465754907);
#
#
#         var popup_c8b60b5dd6d27dd7704d88b393cc8392 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_5705fa394e74cf1f4f548e8d121a34f2 = $(`&lt;div id=&quot;html_5705fa394e74cf1f4f548e8d121a34f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;수로왕릉역&lt;/div&gt;`)[0];
#             popup_c8b60b5dd6d27dd7704d88b393cc8392.setContent(html_5705fa394e74cf1f4f548e8d121a34f2);
#
#
#         marker_46d499ae4e083cafc2db803d9b3e5cdf.bindPopup(popup_c8b60b5dd6d27dd7704d88b393cc8392)
#         ;
#
#
#
#
#             marker_46d499ae4e083cafc2db803d9b3e5cdf.bindTooltip(
#                 `&lt;div&gt;
#                      김해시 외동 1297
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_81307abeeb0d51cf28c5b041714da008 = L.marker(
#                 [35.2334009, 128.8789361],
#                 {}
#             ).addTo(map_c67271472c9d743c7ab0e31465754907);
#
#
#         var popup_0912f6f9e1e7fa82efe02d4322614ee5 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_add50370ba316e96fcb54b2c98b4a08c = $(`&lt;div id=&quot;html_add50370ba316e96fcb54b2c98b4a08c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;수로왕릉&lt;/div&gt;`)[0];
#             popup_0912f6f9e1e7fa82efe02d4322614ee5.setContent(html_add50370ba316e96fcb54b2c98b4a08c);
#
#
#         marker_81307abeeb0d51cf28c5b041714da008.bindPopup(popup_0912f6f9e1e7fa82efe02d4322614ee5)
#         ;
#
#
#
#
#             marker_81307abeeb0d51cf28c5b041714da008.bindTooltip(
#                 `&lt;div&gt;
#                      김해시 서상동 335-1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ee9ec9a59d63a83ea59329fdcba75655 = L.marker(
#                 [35.234852, 128.872881],
#                 {}
#             ).addTo(map_c67271472c9d743c7ab0e31465754907);
#
#
#         var popup_5e0651090adc0129b6267e7f9abf097c = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_62fc38c737c7d69dc91dd0621f85560e = $(`&lt;div id=&quot;html_62fc38c737c7d69dc91dd0621f85560e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;대성동고분박물관&lt;/div&gt;`)[0];
#             popup_5e0651090adc0129b6267e7f9abf097c.setContent(html_62fc38c737c7d69dc91dd0621f85560e);
#
#
#         marker_ee9ec9a59d63a83ea59329fdcba75655.bindPopup(popup_5e0651090adc0129b6267e7f9abf097c)
#         ;
#
#
#
#
#             marker_ee9ec9a59d63a83ea59329fdcba75655.bindTooltip(
#                 `&lt;div&gt;
#                      김해시 봉황동 453-1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8a432b68864de3d65358ab17e7e8c66c = L.marker(
#                 [35.2400377, 128.8718979],
#                 {}
#             ).addTo(map_c67271472c9d743c7ab0e31465754907);
#
#
#         var popup_f5f30b3536f094ab4a41e2f8d8cf99b7 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_205422069c139cfe0fa031fb64c85699 =

# %%
# folium 패키지를 이용하여 모든 스테이션을 지도에 마커로 출력
# 단, 모든 좌표를 대상을 중심 좌표를 구하여 모든 마커가 보이도록 처리
import folium

# 중심 좌표를 각 좌표의 평균으로 한다.

# 문제 1-9 : xCoordinate 평균 값을 중심 좌표로 사용하려고 합니다. 알맞은 함수를 완성하세요.
x_center = real_data.xCoordinate.astype(float).?()
# 문제 1-10 : yCoordinate 평균 값을 중심 좌표로 사용하려고 합니다. 알맞은 함수를 완성하세요.
y_center = real_data.yCoordinate.astype(float).?()

map_figure = folium.Figure(width=700, height=350) # map 크기 변경
map_ = folium.Map(location=[y_center, x_center], zoom_start=13).add_to(map_figure) # 모든 좌표의 중심좌표(평균좌표)의 위도, 경도를 중심으로 지도 구성

for row_index, row in real_data.iterrows():
    popup = folium.Popup(row['name'], min_width=200, max_width=200) # 마커 클릭시 출력할 팝업 메세지 준비
    folium.Marker([row.yCoordinate, row.xCoordinate], popup=popup, tooltip=row.addr).add_to(map_) # 마커 출력
map_  # map 출력
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89f5f211bb2f7c6e6ae5f2a142b3d420 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89f5f211bb2f7c6e6ae5f2a142b3d420&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89f5f211bb2f7c6e6ae5f2a142b3d420 = L.map(
#                 &quot;map_89f5f211bb2f7c6e6ae5f2a142b3d420&quot;,
#                 {
#                     center: [35.23825556470968, 128.87208150806757],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cf056eae05b69bd671587ca29fac39b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_89f5f211bb2f7c6e6ae5f2a142b3d420);
#
#
#             var marker_bccab22c3633804f5cea548116eefff1 = L.marker(
#                 [35.2277057, 128.8736411],
#                 {}
#             ).addTo(map_89f5f211bb2f7c6e6ae5f2a142b3d420);
#
#
#         var popup_c99443e0756b2d8644bd7d1c27c10f87 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_30596dc262306e78a1995d29aaf158d4 = $(`&lt;div id=&quot;html_30596dc262306e78a1995d29aaf158d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;봉황역&lt;/div&gt;`)[0];
#             popup_c99443e0756b2d8644bd7d1c27c10f87.setContent(html_30596dc262306e78a1995d29aaf158d4);
#
#
#         marker_bccab22c3633804f5cea548116eefff1.bindPopup(popup_c99443e0756b2d8644bd7d1c27c10f87)
#         ;
#
#
#
#
#             marker_bccab22c3633804f5cea548116eefff1.bindTooltip(
#                 `&lt;div&gt;
#                      경상남도 김해시 외동 1264
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b700c9879ef89ef750f475adb6640362 = L.marker(
#                 [35.2329938518363, 128.872086162507],
#                 {}
#             ).addTo(map_89f5f211bb2f7c6e6ae5f2a142b3d420);
#
#
#         var popup_3b0345635d920810639d81d50eabc36c = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_ce9582e5560d40d36e44c0b1466d89b1 = $(`&lt;div id=&quot;html_ce9582e5560d40d36e44c0b1466d89b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;수로왕릉역&lt;/div&gt;`)[0];
#             popup_3b0345635d920810639d81d50eabc36c.setContent(html_ce9582e5560d40d36e44c0b1466d89b1);
#
#
#         marker_b700c9879ef89ef750f475adb6640362.bindPopup(popup_3b0345635d920810639d81d50eabc36c)
#         ;
#
#
#
#
#             marker_b700c9879ef89ef750f475adb6640362.bindTooltip(
#                 `&lt;div&gt;
#                      김해시 외동 1297
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_df55d90e1b23575edf11b67246dabb1e = L.marker(
#                 [35.2334009, 128.8789361],
#                 {}
#             ).addTo(map_89f5f211bb2f7c6e6ae5f2a142b3d420);
#
#
#         var popup_5022701124eb8a836dd51ff2a9dff269 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_1784019bfb2c462044a3015896334c73 = $(`&lt;div id=&quot;html_1784019bfb2c462044a3015896334c73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;수로왕릉&lt;/div&gt;`)[0];
#             popup_5022701124eb8a836dd51ff2a9dff269.setContent(html_1784019bfb2c462044a3015896334c73);
#
#
#         marker_df55d90e1b23575edf11b67246dabb1e.bindPopup(popup_5022701124eb8a836dd51ff2a9dff269)
#         ;
#
#
#
#
#             marker_df55d90e1b23575edf11b67246dabb1e.bindTooltip(
#                 `&lt;div&gt;
#                      김해시 서상동 335-1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e15fb4d1823182e0002859a34f9d4edf = L.marker(
#                 [35.234852, 128.872881],
#                 {}
#             ).addTo(map_89f5f211bb2f7c6e6ae5f2a142b3d420);
#
#
#         var popup_40d1b61fbe15ecdf147d002ec84bee63 = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_f63528b2080e39d3c7bafc9087369285 = $(`&lt;div id=&quot;html_f63528b2080e39d3c7bafc9087369285&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;대성동고분박물관&lt;/div&gt;`)[0];
#             popup_40d1b61fbe15ecdf147d002ec84bee63.setContent(html_f63528b2080e39d3c7bafc9087369285);
#
#
#         marker_e15fb4d1823182e0002859a34f9d4edf.bindPopup(popup_40d1b61fbe15ecdf147d002ec84bee63)
#         ;
#
#
#
#
#             marker_e15fb4d1823182e0002859a34f9d4edf.bindTooltip(
#                 `&lt;div&gt;
#                      김해시 봉황동 453-1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4baaf0bb18b14a3f0f76ccd939eed878 = L.marker(
#                 [35.2400377, 128.8718979],
#                 {}
#             ).addTo(map_89f5f211bb2f7c6e6ae5f2a142b3d420);
#
#
#         var popup_d3226447626c78de9c2a3d51789d902e = L.popup({&quot;maxWidth&quot;: 200, &quot;minWidth&quot;: 200});
#
#
#             var html_2c70892d11a3f262addb

# %% [markdown]
# - End Of Program
