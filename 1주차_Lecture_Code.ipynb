# %% [markdown]
# <a href="https://colab.research.google.com/github/trex99/DAVI/blob/main/1%EC%A3%BC%EC%B0%A8_Lecture_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⭕ 학습 로드맵

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 데이터 분석

# %% [markdown]
# ## 데이터 분석의 정의

# %% [markdown]
# ⚓ 원시 데이터에서 실행 가능한 인사이트를 추출하는 일련의 과정
#
# ⚓ 유용한 정보를 발견하고, 의사결정을 지원할 목적으로 하는 프로세스
#
#    - 데이터를 이용한 문제해결의 도구, 기술, 프로세스 등을 포함.
#    - 데이터 가공, 정리, 모델링의 과정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 데이터 분석의 목적

# %% [markdown]
# 💰 분석 주체의 문제해결(정부, 기업, 학교 등)
#
# 💰 의사결정 개선
#
# 💰 기업 가치 창출 및 성장

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 시각화

# %% [markdown]
# ## 시각화 정의

# %% [markdown]
# 👀 데이터 분석 결과를 쉽게 이해할 수 있도록 시각적으로 표현하고 전달되는 과정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 시각화 목적

# %% [markdown]
# 💑 그래프를 이용하여 정보를 명확하고 효과적으로 전달하는 것
#
# 💑 데이터에서 이상치, 패턴 등 주요 정보를 신속하고 용이하게 발견
#
# 💑 정보를 효율적이고 명확하게 제공

# %% [markdown]
# # Colab 소개

# %% [markdown]
# ## Colab 이란 ?

# %% [markdown]
# - Colaboratory(줄여서 'Colab'이라고 함)을 통해 웹 브라우저에서 Python 스크립트를 작성하고 실행하는 도구
# - 구성이 필요하지 않음
# - GPU 무료 액세스
# - 간편한 공유
#
#       ※ 이미 설치된 가상환경에서의 Jupyter Notebook
#
#     👉 [Jupyter Organization](https://jupyter.org/)

# %% [markdown]
# ## Colab 한계

# %% [markdown]
# - 시간 제한
# - 하나의 작업을 최대 12시간까지만 연속 사용 가능
# - 1시간 이상 미사용시 초기화
# - 서버에 원격 접속하여 작업하는 환경
# - 대용량 데이터 분석이 불편
# - 외부 반출할 수 없는 데이터는 분석할 수 없음
#       ※ 정책에 따라 조금씩 다를 수 있음

# %% [markdown]
# ## Colab 사용 순서

# %% [markdown]
# - Google 계정 생성 (단, 공유된 프로그램을 보기만 할 때는 불필요)
# - Google 계정 로그인
# - Colab 접속

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 👉 [Colaboratory 접속](https://colab.research.google.com/)

# %% [markdown]
# - 알아두면 개발에 편리한 메뉴(기능)
#       - 파일 > 저장
#       - 파일 > 노트 업로드 (불러오기)
#       - 파일 > 다운로드
#       - 브라우저 > 인쇄 (프로그램 PDF 전환 가능)
#       - 단축키 몇 가지
#            - Ctrl+M+B : 코드 셀 삽입
#            - Ctrl+M+D : 코드 셀 삭제

# %% [markdown]
# # 실습파일(*.ipynb) 다운로드하는 방법

# %% [markdown]
# ## Google Drive에서 다운로드

# %% [markdown]
# 📁 실습파일 공유 경로(URL) 접속 : https://drive.google.com/drive/folders/18IgSwhDxgUE0d7tXLc8xkGe5MpUQ9jCf?usp=share_link

# %% [markdown]
# ⚛ (권장) 실습 방법 #1 : 파일을 모두 다운로드 받은 후 필요할 때 Colab에 업로드 후 실습
#
# ⚛ 실습 방법 #2 : 파일을 모두 다운로드 받은 후 본인 Google Drive에 업로드 후 실습

# %% [markdown]
# ## Github에서 다운로드(clone)

# %% [markdown]
# 📁 실습파일 공유 경로(URL) 접속 : https://www.github.com/trex99/DAVI

# %% [markdown]
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# ⚛ (권장) 실습 방법 #1 : 파일을 모두 다운로드 받은 후 필요할 때 Colab에 업로드 후 실습
#
# ⚛ 실습 방법 #2 : 파일을 모두 다운로드 받은 후 본인 Google Drive에 업로드 후 실습
#
# ⚛ 실습 방법 #3 : 공유된 DAVI 레포지토리를 fork하여 본인 github로 복제 후 실습

# %% [markdown]
# ## Google Drive ↔ Colab 연동(노트북)

# %% [markdown]
# 1. Google Drive 실습 경로에 접속 후 우측 상단이 로그인 상태가 아니면 로그인 버튼 클릭 후 로그인
#
#   ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. 로그인 후 화면이 전환되면 실습하고자 하는 파일을 더블 클릭

# %% [markdown]
# - 더블 클릭 후 화면 이동 시 로그인 요청이 있을 수 있습니다.
# - 더블 클릭 후 Colaboratory에서 바로 열리지 않으면 연결 작업을 해야 합니다.
# - Google Drive에 저장된 ipynb 파일을 colab과 연동하는 방법
#
#    ![image.png](data:image/png;base64,...)
#
# - 연동대상 파일을 선택 후 우클릭 -> 연결 앱 -> 연결할 앱 더보기
# - Google Colaboratory 앱 설치
