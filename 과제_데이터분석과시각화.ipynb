# %% [markdown]
# <a href="https://colab.research.google.com/github/trex99/DAVI/blob/main/%EA%B3%BC%EC%A0%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EA%B3%BC%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 과목명 : 데이터분석과 시각화

# %% [markdown]
# ## 과제설명

# %% [markdown]
# 1. 아래 내용을 읽고 각 문제를 해결하는 코드를 완성하여 PDF로 제출하시기 바랍니다.
# 2. PDF가 아닌 노트북 파일 또는 Colab을 공유하여 제출하는 경우 감점이 됩니다.
# 3. 코드 이외 설명하는 내용 등 코드와 관계없는  내용이 포함되어도 관계없습니다.

# %% [markdown]
# ## 과제제출

# %% [markdown]
# - 15주차 기말고사 일자이전에 제출

# %% [markdown]
# <hr>

# %% [markdown]
# ## 문제상황

# %% [markdown]
# ### 데이타 사전 지식

# %% [markdown]
# YouTube(세계적으로 유명한 동영상 공유 웹사이트)는 플랫폼에서 가장 인기 있는 동영상 목록을 관리합니다.
#
# 버라이어티 매거진에 따르면 올해의 최고 인기 동영상을 결정하기 위해 YouTube는 사용자 상호 작용(조회 수, 공유 수, 댓글 및 좋아요 수)을 측정하는 등 여러 요인을 조합하여 사용합니다. 해당 연도 전체에서 가장 많이 본 동영상은 아닙니다.
#
# YouTube 트렌딩 목록의 최고 성능은 뮤직 비디오(유명하게 남성적인 "Gangam Style" 등), 유명인 및/또는 리얼리티 TV 공연, YouTube에서 잘 알려진 무작위 카메라 바이럴 동영상입니다.
#
# 분석대상 데이터 셋은 인기 급상승 YouTube 동영상의 일일 기록입니다.

# %% [markdown]
# ### 분석대상 데이터셋

# %% [markdown]
# - 분석 대상 데이터셋 : https://www.kaggle.com/datasets/datasnaek/youtube-new?select=KRvideos.csv
# - 학습 공유 구글 드라이브에도 있습니다
# - 파일명 : KRvideos.csv

# %% [markdown]
# ### 과제 목표

# %% [markdown]
# - 분석 대상 데이터셋을 불러와 기술 통계정보를 확인합니다.
# - 결측치를 확인하고 0 으로 치환 처리합니다.
# - 중복된 데이터가 있다면 데이터 건수를 확인하고 삭제합니다.
# - 채널별 조회수 합계를 구하고 시각화합니다.
# - 채널별 조회수 합계를 구하고 상위 100건에 대해 시각화합니다.
# - 'title','views'만 선택하여 많은 views 순으로 정렬 후 중복을 제거합니다.
# - 'title' 컬럼 값을 이용하여 한글만 워드 클라우드 시각화를 합니다.
# - 'views', 'likes', 'dislikes', 'comment_count' 컬럼 값의 상관계수 heatmap() 시각화를 합니다.
# - 'category_id', 'views', 'likes', 'comment_count' 컬럼을 이용하여 유의미한 scatterplot(), barplot(), histplot(), countplot() 등 시각화를 합니다.

# %%
import pandas as pd

KRvideo = pd.read_csv("KRvideos.csv")
KRvideo
# Out:
#           video_id trending_date                                  title  \
# 0      RxGQe4EeEpA      17.14.11                     좋아 by 민서_윤종신_좋니 답가
# 1      hH7wVE8OlQ0      17.14.11                       JSA 귀순 북한군 총격 부상
# 2      9V8bnWUmE9U      17.14.11             나몰라패밀리 운동화 영상 2탄 (빼빼로데이버젼)
# 3      0_8py-t5R80      17.14.11             이명박 출국 현장, 놓치면 안되는 장면
# 4      bk55RbxiQdI      17.14.11                김장겸은 물러갔다 MBC 노조 환호와 눈물
# ...            ...           ...                                    ...
# 34560  pj6YBBrO1sQ      18.14.06             장모님 가게한다고 1억만 달라는 아내 사이다카톡
# 34561  _Ne9ER-jr20      18.14.06        여러분~ 렌즈가 이렇게 위험합니다!!!ㅜㅜ _[이슈텔러]
# 34562  xuOQq_fzEjk      18.14.06                     2018년 6월 13일 아침 뉴스
# 34563  uXvjxeg08eQ      18.14.06          워너원 웃음 참기 영상 워너원 GO X-con.ver
# 34564  C-bLqIftDY4      18.14.06  [법륜스님의 즉문즉설 제 1398회] 시동생의 아이를 키우게 됐어요
#
#           channel_title  category_id              publish_time  \
# ...

# %%
KRvideo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34565 entries, 0 to 34564
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                34565 non-null  object
#  1   trending_date           34565 non-null  object
#  2   title                   34565 non-null  object
#  3   channel_title           34565 non-null  object
#  4   category_id             34565 non-null  int64
#  5   publish_time            34565 non-null  object
#  6   tags                    34565 non-null  object
#  7   views                   34565 non-null  int64
#  8   likes                   34565 non-null  int64
#  9   dislikes                34565 non-null  int64
#  10  comment_count           34565 non-null  int64
#  11  thumbnail_link          34565 non-null  object
#  12  comments_disabled       34565 non-null  bool
#  13  ratings_disabled        34565 non-null  bool
# ...

# %%
KRvideo.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  34565.000000  3.456500e+04  3.456500e+04  3.456500e+04   3.456500e+04
# mean      21.137625  4.249711e+05  1.218712e+04  5.391290e+02   2.025499e+03
# std        6.675645  2.430705e+06  1.170565e+05  1.370891e+04   2.150738e+04
# min        1.000000  2.050000e+03  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       22.000000  4.777100e+04  4.120000e+02  2.100000e+01   1.050000e+02
# 50%       24.000000  1.115280e+05  1.389000e+03  6.500000e+01   3.450000e+02
# 75%       25.000000  2.788770e+05  3.705000e+03  1.750000e+02   9.290000e+02
# max       44.000000  1.138762e+08  5.150839e+06  1.470388e+06   1.142274e+06

# %%
KRvideo.corr()
# Out:
#                         category_id     views     likes  dislikes  \
# category_id                1.000000 -0.082366 -0.097975 -0.016724
# views                     -0.082366  1.000000  0.860043  0.581443
# likes                     -0.097975  0.860043  1.000000  0.428036
# dislikes                  -0.016724  0.581443  0.428036  1.000000
# comment_count             -0.065037  0.807600  0.922731  0.555549
# comments_disabled          0.026885 -0.003380 -0.010735 -0.002056
# ratings_disabled           0.054088 -0.019286 -0.021391 -0.008080
# video_error_or_removed    -0.042890 -0.002113 -0.000232 -0.000589
#
#                         comment_count  comments_disabled  ratings_disabled  \
# category_id                 -0.065037           0.026885          0.054088
# views                        0.807600          -0.003380         -0.019286
# likes                        0.922731          -0.010735         -0.021391
# ...
